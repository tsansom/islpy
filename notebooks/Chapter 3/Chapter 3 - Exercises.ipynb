# %% [markdown]
# ## Conceptual

# %% [markdown]
# **1**:
# The null hypothesis are that the advertising budgets of TV, radio, and newspaper have no effect on sales. More precisely $H_0^{(1)}: \beta_1 = 0$, $H_0^{(2)}: \beta_2 = 0$, and $H_0^{(3)}: \beta_3 = 0$. The p-values for TV and radio are significant while the p-value for newspaper is not significant. So, we reject the null hypotheses $H_0^{(1)}$ and $H_0^{(2)}$ and we do not reject $H_0^{(3)}$.

# %% [markdown]
# **2**:
# The KNN classifier is used for classifying a qualitative response by identifying the $K$ closest observations (represented by $N_0$) to a prediction point $x_0$, then estimating the conditional probability $P(Y = j | X = x_0)$ for class $j$ as the fraction of points in $N_0$ whose response values equal j.
#
# Conversely, the KNN regressor is used for predicting a qualitative response by identifying the $K$ closest observations (represented by $N_0$) to a prediction point $x_0$, then estimating $f(x_0)$ using the average of all the training responses in $N_0$.

# %% [markdown]
# **3 (a)**:
# $$\hat{salary} = \widehat{\beta}_0 + \widehat{\beta}_1X_1 + \widehat{\beta}_2X_2 + \widehat{\beta}_3X_3 + \widehat{\beta}_4X_4 + \widehat{\beta}_5X_5$$
#
# $$\hat{salary} = 50 + 20(GPA) + 0.07(IQ) + 35(Gender) + 0.01(GPA:IQ) - 10(GPA:Gender)$$
#
# $$Gender = \begin{cases}1 & \text{if Female}\\0 & \text{if Male}\end{cases}$$
#
# $$\hat{salary} = \begin{cases}
# 50 + 20(GPA) + 0.07(IQ) + 35 +0.01(GPA:IQ) - 10(GPA) & \text{if Female}\\
# 50 + 20(GPA) + 0.07(IQ) +0.01(GPA:IQ) & \text{if Male}
# \end{cases}$$
#
# which reduces to
#
# $$\hat{salary} = \begin{cases}
# 85 + 10(GPA) + 0.07(IQ) + 0.01(GPA:IQ) & \text{if Female}\\
# 50 + 20(GPA) + 0.07(IQ) + 0.01(GPA:IQ) & \text{if Male}
# \end{cases}$$
#
# So the starting salary for males is higher if $50 + 20(GPA) > 85 + 10(GPA)$ which is equivalent to $GPA > 3.5$. This means that **iii** is the correct answer.
#
# **3 (b)**:
# We can simply plug in the GPA and IQ into the equation above for females to get the estimated salary
#
# $$\hat{salary} = 85 + 10(4) + 0.07(110) + 0.01(4\times110)$$
#
# $$ = $137,100$$.
#
# **3 (c)**:
# *False*. In order to verify the impact that $GPA:IQ$ has on salary, we would need to test the null hypothesis $H_0: \widehat{\beta}_4 = 0$ and then look at the p-values to determine statistical significance.

# %% [markdown]
# **4 (a)**:
# I would expect the training RSS to be slightly lower for the cubic regression (see figure 2.10) because the increased flexibility of the model will provide a tighter fit to the training data. However, I do not expect a large difference between the training RSS's for linear and cubic regressions.
#
# **4 (b)**:
# I would expect the linear regression to have a lower test RSS if the true relationship between $X$ and $Y$ is linear. The higher test RSS for the cubic regression stems from the potential overfitting due to unneccesary increased flexibility of the model.
#
# **4 (c)**:
# Similar to **4 (a)**, I would expect the training RSS to be lower for the cubic regression. The more flexible model will produce a closer fit to the training data than a linear model. In this case, the difference between the linear regression and cubic regression training RSS will be much higher than in **4 (a)**.
#
# **4 (d)**:
# There is not enough information to tell whether the test RSS will be lower for the linear regression or the cubic regression models. The problem is that we don't know how far from linear the relationship between $X$ and $Y$ is. If it is closer to a linear function than a cubic function, the linear regression will have a lower test RSS. On the other hand, if the relationship is closer to a cubic function than a linear function, the cubic regression will result in the lower test RSS.

# %% [markdown]
# **5**:
# $$\widehat{y}_i = x_i\widehat{\beta}$$
#
# and
#
# $$\widehat{\beta} = \frac{\sum_{i=1}^nx_iy_i}{\sum_{i^{\prime}=1}^nx_{i^{\prime}}^2}$$
#
# combining the two and reindexing the summations we get
#
# $$\widehat{y}_i = x_i\frac{\sum_{j=1}^nx_jy_j}{\sum_{k=1}^nx_{k}^2}$$
#
# Since $x_i$ is a constant relative to the summation over $j$, it can be brought inside the sum. Thus, we can rewrite this as
#
# $$\widehat{y}_i = \sum_{j=1}^n\frac{x_ix_j}{\sum_{k=1}^nx_k^2}y_j = \sum_{j=1}^na_jy_j$$
#
# where
#
# $$a_j = \frac{x_ix_j}{\sum_{k=1}^nx_k^2}$$

# %% [markdown]
# **6**:
# The simple linear regression equation is
#
# $$y = \widehat{\beta}_0 + \widehat{\beta}_1x$$
#
# From (3.4)
#
# $$\widehat{\beta}_0 = \bar{y} - \widehat{\beta}_1\bar{x}$$
#
# Substituting this into the simple linear regression we get
#
# $$y = \bar{y} - \widehat{\beta}_1\bar{x} + \widehat{\beta}_1x$$
#
# The right-hand side of this equation will equal zero if the point $(\bar{x}, \bar{y})$ is on the line. We can check this by substituting $\bar{x}$ for $x$ in the above equation and checking that $y = \bar{y}$
#
# $$y = \bar{y} - \widehat{\beta}_1\bar{x} + \widehat{\beta}_1\bar{x}$$
#
# $$y = \bar{y}$$
#
# Thus the simple linear regression line always passes through the point $(\bar{x}, \bar{y})$

# %% [markdown]
# **7**:
# $$R^2 = 1 - \frac{RSS}{TSS}$$
#
# where
#
# $$RSS = \sum_{i=1}^n(y_i - \widehat{y}_i)^2\qquad\text{and}\qquad TSS = \sum_{i=1}^n(y_i - \bar{y})^2$$
#
# Assuming $\bar{x} = \bar{y} = 0$ (and consequently $\widehat{\beta}_0 = \bar{y} - \widehat{\beta}_1\bar{x} = 0$) we can rewrite $R^2$ as
#
# $$R^2 = 1 - \frac{\sum_{i=1}^n(y_i - \widehat{y}_i)^2}{\sum_{i=1}^ny_i^2}$$
#
# Remembering that $\widehat{y}_i = \widehat{\beta}_1x_i$ (since $\widehat{\beta}_0 = 0)$, this equation becomes
#
# $$R^2 = 1 - \frac{\sum_{i=1}^n(y_i - \widehat{\beta}_1x_i)^2}{\sum_{i=1}^ny_i^2}$$
#
# $$=\frac{\sum_{j=1}^ny_j^2}{\sum_{j=1}^ny_j^2} - \frac{\sum_{i=1}^n(y_i^2 - 2x_iy_i\widehat{\beta}_1 + x_i^2\widehat{\beta}_1^2)}{\sum_{j=1}^ny_j^2}$$
#
# $$=\frac{\sum_{j=1}^ny_j^2 - \sum_{i=1}^ny_i^2 + 2\widehat{\beta}_1\sum_{i=1}^nx_iy_i - \widehat{\beta}_1^2\sum_{i=1}^nx_i^2}{\sum_{j=1}^ny_j^2}$$
#
# Also, since $\bar{x} = \bar{y} = 0$ we can write $\widehat{\beta}_1$ as
#
# $$\widehat{\beta}_1 = \frac{\sum_{i=1}^nx_iy_i}{\sum_{i=1}^nx_i^2}$$
#
# Substuting this into the equation and cancelling the first two terms in the numerator we get
#
# $$R^2 = \frac{2\frac{\sum_{i=1}^nx_iy_i}{\sum_{i=1}^nx_i^2}\sum_{i=1}^nx_iy_i - \bigl(\frac{\sum_{i=1}^nx_iy_i}{\sum_{i=1}^nx_i^2}\bigr)^2\sum_{i=1}^nx_i^2}{\sum_{i=1}^ny_i^2}$$
#
# $$= \frac{2\frac{(\sum_{i=1}^nx_iy_i)^2}{\sum_{x=1}^nx_i^2} - \frac{(\sum_{x=1}^nx_iy_i)^2}{\sum_{x=1}^nx_i^2}}{\sum_{i=1}^ny_i^2}$$
#
# $$\boxed{R^2 = \frac{(\sum_{i=1}^nx_iy_i)^2}{\sum_{i=1}^nx_i^2\sum_{i=1}^ny_i^2}}$$
#
# From equation 3.18, the correlation is defined as
#
# $$Cor(X, Y) = \frac{\sum_{i=1}^n(x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum_{i=1}^n(x_i - \bar{x})^2}\sqrt{\sum_{i=1}^n(y_i - \bar{y})^2}}$$
#
# Assuming $\bar{x} = \bar{y} = 0$, the squared correlation reduces to
#
# $$Cor(X, Y)^2 = \frac{(\sum_{i=1}^nx_iy_i)^2}{\sum_{i=1}^nx_i^2\sum_{i=1}^ny_i^2}$$
#
# Which is exactly the form we got for $R^2$ in the boxed equation above

# %% [markdown]
# ## Applied

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# **8**:

# %%
auto = pd.read_csv('../../data/Auto.csv', na_values='?')
auto_ols = smf.ols('mpg ~ horsepower', auto).fit()
auto_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           7.03e-81
# Time:                        08:59:47   Log-Likelihood:                -1178.7
# No. Observations:                 392   AIC:                             2361.
# Df Residuals:                     390   BIC:                             2369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.9359      0.717     55.660      0.000      38.525      41.347
# ...

# %% [markdown]
# **8 (a) i**:
# We can test the null hypothesis that all regression coefficients are equal to zero, i.e. $H_0: \beta_i = 0\space \forall \space i$. The p-value corresponding to the F-statistic is 7.03e-81 which clearly indicates a relationship betwen mpg and horsepower. Thus, we can reject the null hypothesis.
#
# **8 (a) ii**:

# %%
mpg_pred = auto_ols.predict()
n = len(auto.dropna())
RSS = ((auto.dropna()['mpg'].values - mpg_pred)**2).sum()
RSE = np.sqrt((1/(n-2))*RSS)
mpg_mean = auto['mpg'].mean()
print('Percentage Error: {:.2f}%'.format(RSE / mpg_mean * 100))
# Out:
# Percentage Error: 20.86%

# %% [markdown]
# To calculate the error relative to the response (mpg), we use the mean of the response and the RSE. The calculations above provide a percentage error of 20.86%. We can also see that the $R^2$ value of 0.606 indicates that almost 61% of the variance in mpg can be explained with horsepower.
#
# **8 (a) iii**:
# The relationship between mpg and horsepower is negative because the coefficient associated with horsepower in the ols summary above is negative. This means that increasing the horsepower by one unit will decrease the mpg by 0.1578 units.
#
# **8 (b) iv**:

# %%
auto_pred = auto_ols.get_prediction({'horsepower': [98]}).summary_frame()
print('Prediction: {:.4f}\nConfidence Interval: {:.4f} to {:.4f}' \
      '\nPrediction Interval: {:.4f} to {:.4f}' \
      .format(auto_pred['mean'][0], 
              auto_pred['mean_ci_lower'][0],
              auto_pred['mean_ci_upper'][0], 
              auto_pred['obs_ci_lower'][0],
              auto_pred['obs_ci_upper'][0]))
# Out:
# Prediction: 24.4671
# Confidence Interval: 23.9731 to 24.9611
# Prediction Interval: 14.8094 to 34.1248

# %% [markdown]
# **8 (b)**:

# %%
sns.regplot(x=auto['horsepower'], y=auto['mpg'], line_kws={'color': 'red'})

# %% [markdown]
# **8 (c)**:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

sns.residplot(auto_ols.predict(), auto_ols.resid, lowess=True, 
              line_kws={'color': 'red'}, ax=ax1)
ax1.set(xlabel='Fitted Values', ylabel='Residuals')
ip = sm.graphics.influence_plot(auto_ols, ax=ax2)
ax2.set(xlim=[0, 0.035])
# Out:
# [(0, 0.035)]

# %% [markdown]
# The left hand plot of residuals versus predicted values for mpg indicate the presence of non-linearity in the relationship between mpg and horsepower. The right hand plot of leverage versus studentized residuals indicates the presence of outliers (studentized residuals higher than 2 or lower than -2) and a few high leverage observation points.

# %% [markdown]
# **9 (a)**:

# %%
sns.pairplot(auto.dropna());

# %% [markdown]
# **9 (b)**:

# %%
corr = auto.dropna().corr()
fig, ax1 = plt.subplots(1, 1, figsize=(8, 6))
sns.heatmap(corr, annot=True, ax=ax1)

# %% [markdown]
# **9 (c)**:

# %%
#string for formula with predictors (minus mpg and name)
predictors = ' + '.join(auto.columns[1:-1])
auto_ols = smf.ols('mpg ~ {}'.format(predictors), auto).fit()
auto_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     252.4
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):          2.04e-139
# Time:                        08:59:54   Log-Likelihood:                -1023.5
# No. Observations:                 392   AIC:                             2063.
# Df Residuals:                     384   BIC:                             2095.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# **9 (c) i**:
# As in 8 (a) i, we can test the null hypothesis that all regression coefficients are equal to zero, i.e. $H_0: \beta_i = 0\space \forall \space i$. The p-value associated with the F-statistic is 2.04e-139 which indicatees there there is a relationship between mpg and the other predictors. Thus, we reject the null hypothesis.
#
# **9 (c) ii**:
# Based on the p-values for each predictor, we may conclude that all the predictors are significantly significant in the current model except cylinders, horsepower, and acceleration.
#
# **9 (c) iii**:
# The coefficient for the year predictor is 0.7508. This indicates for a one-unit increase in year, the mpg will increase by 0.75 (with all other predictors remaining constant). The interpretation of this is that cars become more fuel efficient by 0.75 mpg every year.
#
# **9 (d)**:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

sns.residplot(auto_ols.predict(), auto_ols.resid, lowess=True, 
              line_kws={'color': 'red'}, ax=ax1)
ax1.set(xlabel='Fitted Values', ylabel='Residuals')
ip = sm.graphics.influence_plot(auto_ols, ax=ax2)
ax2.set(xlim=[0, 0.21], ylim=[-4, 5])
# Out:
# [(-4, 5), (0, 0.21)]

# %% [markdown]
# Once again we see from the left hand panel mild non-linearity in the data. In the right panel we can see the presence of some outliers (studentized residuals higher than 2 or lower than -2) and one very high leverage point (13).
#
# **9 (e)**

# %%
auto_ols = smf.ols('mpg ~ cylinders*displacement + displacement*weight', 
                   auto).fit()
auto_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.727
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     208.2
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):          7.95e-108
# Time:                        08:59:55   Log-Likelihood:                -1122.0
# No. Observations:                 397   AIC:                             2256.
# Df Residuals:                     391   BIC:                             2280.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Using the two highest correlated predictors from the correlation matrix, we can see that the p-values for the cylinders:displacement interaction (0.399) indicate that interaction is not significant. However, the p-values for the displacement:weight interaction (0.000) indicate statistical significance of this interaction.

# %% [markdown]
# **9 (f)**:

# %%
#horsepower
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4))
sns.regplot(np.log(auto['horsepower']), auto['mpg'], 
            line_kws={'color': 'red'}, ci=False, ax=ax1)
sns.regplot(np.sqrt(auto['horsepower']), auto['mpg'],
            line_kws={'color': 'red'}, ci=False, ax=ax2)
sns.regplot(auto['horsepower']**2, auto['mpg'], 
            line_kws={'color': 'red'}, ci=False, ax=ax3)
fig.suptitle('Horsepower Transformations')
ax1.set_title('Log')
ax2.set_title('Square Root')
ax3.set_title('Squared')

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4))
sns.regplot(np.log(auto['displacement']), auto['mpg'], 
            line_kws={'color': 'red'}, ci=False, ax=ax1)
sns.regplot(np.sqrt(auto['displacement']), auto['mpg'],
            line_kws={'color': 'red'}, ci=False, ax=ax2)
sns.regplot(auto['displacement']**2, auto['mpg'], 
            line_kws={'color': 'red'}, ci=False, ax=ax3)
fig.suptitle('Displacement Transformations')
ax1.set_title('Log')
ax2.set_title('Square Root')
ax3.set_title('Squared')

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4))
sns.regplot(np.log(auto['weight']), auto['mpg'], 
            line_kws={'color': 'red'}, ci=False, ax=ax1)
sns.regplot(np.sqrt(auto['weight']), auto['mpg'],
            line_kws={'color': 'red'}, ci=False, ax=ax2)
sns.regplot(auto['weight']**2, auto['mpg'], 
            line_kws={'color': 'red'}, ci=False, ax=ax3)
fig.suptitle('Weight Transformations')
ax1.set_title('Log')
ax2.set_title('Square Root')
ax3.set_title('Squared')

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4))
sns.regplot(np.log(auto['acceleration']), auto['mpg'], 
            line_kws={'color': 'red'}, ci=False, ax=ax1)
sns.regplot(np.sqrt(auto['acceleration']), auto['mpg'],
            line_kws={'color': 'red'}, ci=False, ax=ax2)
sns.regplot(auto['acceleration']**2, auto['mpg'], 
            line_kws={'color': 'red'}, ci=False, ax=ax3)
fig.suptitle('Acceleration Transformations')
ax1.set_title('Log')
ax2.set_title('Square Root')
ax3.set_title('Squared')

# %%
auto_ols = smf.ols('mpg ~ np.log(horsepower) + np.sqrt(displacement)' \
                   ' + np.log(weight) + acceleration + I(acceleration**2)', 
                   auto).fit()
auto_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     234.3
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):          1.62e-114
# Time:                        08:59:57   Log-Likelihood:                -1087.8
# No. Observations:                 392   AIC:                             2188.
# Df Residuals:                     386   BIC:                             2211.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

sns.residplot(auto_ols.predict(), auto_ols.resid, lowess=True, 
              line_kws={'color': 'red'}, ax=ax1)
ax1.set(xlabel='Fitted Values', ylabel='Residuals')
ip = sm.graphics.influence_plot(auto_ols, ax=ax2)
ax2.set(xlim=[0, 0.15], ylim=[-4, 5]);

# %% [markdown]
# The tranformed variables $log(horsepower)$, $\sqrt{displacement}$, $log(weight)$, and $acceleration^2$ all show statistical significance of some sort. However, the left panel of the above figure indicates heteroskedasticity (unconstant variance of residuals) in the model. To combat this let's use $log(mpg)$ as our response.

# %%
auto_ols = smf.ols('np.log(mpg) ~ np.log(horsepower) + np.sqrt(displacement)' \
                   ' + np.log(weight) + acceleration + I(acceleration**2)', 
                   auto).fit()
auto_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            np.log(mpg)   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     324.0
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):          1.09e-135
# Time:                        08:59:58   Log-Likelihood:                 190.13
# No. Observations:                 392   AIC:                            -368.3
# Df Residuals:                     386   BIC:                            -344.4
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

sns.residplot(auto_ols.predict(), auto_ols.resid, lowess=True, 
              line_kws={'color': 'red'}, ax=ax1)
ax1.set(xlabel='Fitted Values', ylabel='Residuals')
ip = sm.graphics.influence_plot(auto_ols, ax=ax2)
ax2.set(xlim=[0, 0.15], ylim=[-4, 5])
# Out:
# [(-4, 5), (0, 0.15)]

# %% [markdown]
# **10 (a)**:

# %%
carseats = pd.read_csv('../../data/Carseats.csv', index_col=0)
carseats.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 1   9.50        138      73           11         276    120       Bad   42
# 2  11.22        111      48           16         260     83      Good   65
# 3  10.06        113      35           10         269     80    Medium   59
# 4   7.40        117     100            4         466     97    Medium   55
# 5   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 1         17   Yes  Yes
# 2         10   Yes  Yes
# 3         12   Yes  Yes
# 4         14   Yes  Yes
# 5         13   Yes   No

# %%
carseats_ols = smf.ols('Sales ~ Price + Urban + US', carseats).fit()
carseats_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     41.52
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           2.39e-23
# Time:                        08:59:59   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1863.
# Df Residuals:                     396   BIC:                             1879.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# **10 (b)**:
# #### Price
# The price predictor is statistically significant based on the low p-value. The coefficient suggests a negative relationship between price and sales (price goes up, sales go down).
#
# #### Urban - Yes
# The high p-value suggests that this relationship is not statistically significant.
#
# #### US - Yes
# The low p-value suggests that this relationship is statistically significant with a positive relationship between stores located in the US and sales. If the store is located in the US (with all other predictors held equal), the sales will increase, on average, by 1.2 units.
#
# **10 (c)**:
# $$sales = 13.04 - 0.05 \times Price - 0.02 \times Urban[Yes] + 1.20 \times US[Yes] + \epsilon$$
#
# **10 (d)**:
# We can reject the null hypothesis for Price and US[Yes] based on the low p-values.
#
# **10 (e)**:

# %%
carseats_ols = smf.ols('Sales ~ Price + US', carseats).fit()
carseats_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     62.43
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           2.66e-24
# Time:                        08:59:59   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1861.
# Df Residuals:                     397   BIC:                             1873.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.0308      0.631     20.652      0.000      11.790      14.271
# ...

# %% [markdown]
# **10 (f)**:

# %%
sales_pred = carseats_ols.predict()
n = len(carseats.dropna())
RSS = ((carseats.dropna()['Sales'].values - sales_pred)**2).sum()
RSE = np.sqrt((1/(n-2))*RSS)
print('RSE: {:.4f}'.format(RSE))
# Out:
# RSE: 2.4663

# %% [markdown]
# Based on the $R^2$, adjusted $R^2$, and the RSE of the two linear regressions, they both fit the data similarly with (e) fitting the data slightly better. The value of $R^2$ suggests that these models explain about 23.9% of the variance.
#
# **10 (g)**:

# %%
carseats_conf_int = carseats_ols.conf_int(alpha=0.05)
carseats_conf_int.columns = ['5%', '95%']
print('Confidence Intervals: \n{}'.format(carseats_conf_int))
# Out:
# Confidence Intervals:
#                  5%        95%
# Intercept  11.79032  14.271265
# US[T.Yes]   0.69152   1.707766
# Price      -0.06476  -0.044195

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(6, 5))

ip = sm.graphics.influence_plot(carseats_ols, ax=ax1)
ax1.set(xlim=[0, 0.05], ylim=[-4, 4]);

# %% [markdown]
# The plot of studentized residuals versus leverage shows a few outliers (studentized residuals higher than 2 or lower than -2) and some high leverage points (greatly exceeding $\frac{p + 1}{n} = .0075$)

# %% [markdown]
# **11 (a)**:

# %%
np.random.seed(0)
x = np.random.normal(size=100)
y = 2 * x + np.random.normal(size=100)
y_ols = smf.ols('y ~ x + 0', pd.DataFrame({'x': x, 'y': y})).fit()
y_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     426.4
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           1.16e-37
# Time:                        08:59:59   Log-Likelihood:                -144.94
# No. Observations:                 100   AIC:                             291.9
# Df Residuals:                      99   BIC:                             294.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x              2.1191      0.103     20.650      0.000       1.915       2.323
# ...

# %% [markdown]
# $\widehat{\beta} = 2.1191$
# $\text{Standard Error} = 0.103$
# $\text{t-statistic} = 20.650$
# $\text{p-value} = 0.000$
#
# Based on the small p-value, we reject the null hypothesis $H_0: \widehat{\beta} = 0$

# %% [markdown]
# **11 (a)**:

# %%
x_ols = smf.ols('x ~ y + 0', pd.DataFrame({'x': x, 'y': y})).fit()
x_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      x   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     426.4
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           1.16e-37
# Time:                        08:59:59   Log-Likelihood:                -59.401
# No. Observations:                 100   AIC:                             120.8
# Df Residuals:                      99   BIC:                             123.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# y              0.3830      0.019     20.650      0.000       0.346       0.420
# ...

# %% [markdown]
# $\widehat{\beta} = 0.3830$
# $\text{Standard Error} = 0.019$
# $\text{t-statistic} = 20.650$
# $\text{p-value} = 0.000$
#
# Based on the small p-value, we reject the null hypothesis $H_0: \widehat{\beta} = 0$
#
# **11 (c)**
# We obtain the same t-statistic and p-value for each of the models. Both results reflect the same line created in 11a. In other words $y = 2x + \epsilon$ could be rewritten as $x = 0.5(y - \epsilon)$. In the absence of irreducible error $\epsilon$, the coefficients from (a) and (b) would be inverse of each other (i.e. $\widehat{\beta}_x = \frac{1}{\widehat{\beta}_y}$).

# %% [markdown]
# **11 (d)**:
# Assuming $\bar{x} = \bar{y} = 0$ (which is true considering we created the $x$ with random variables from a normal distribution centered at zero) we have these three equations to work with.
#
# $$t = \frac{\widehat{\beta}}{SE(\widehat{\beta}}\qquad\qquad \widehat{\beta} = \frac{\sum_{i=1}^nx_iy_i}{\sum_{i=1}^nx_i^2}\qquad\qquad SE(\widehat{\beta}) = \sqrt{\frac{\sum_{i=1}^n(y_i - x_i\widehat{\beta})^2}{(n-1)\sum_{i=1}^nx_i^2}}$$
#
# Therefore
#
# $$t = \frac{\sum_{i=1}^nx_iy_i}{\sum_{i=1}^nx_j^2}\sqrt{\frac{(n-1)\sum_{i=1}^nx_i^2}{\sum_{i=1}^n(y_i - x_i\widehat{\beta})^2}}$$
#
# $$= \frac{\sqrt{n-1}\sum_{i=1}^nx_iy_i}{\sqrt{\sum_{j=1}^nx_j^2\sum_{i=1}^n(y_i - x_i\widehat{\beta})^2}}$$
#
# $$= \frac{\sqrt{n-1}\sum_{i=1}^nx_iy_i}{\sqrt{(\sum_{i=1}^nx_i^2)\sum_{i=1}^n(y_i^2 -2x_iy_i\widehat{\beta} + x_i^2\widehat{\beta}^2)}}$$
#
# $$= \frac{\sqrt{n-1}\sum_{i=1}^nx_iy_i}{\sqrt{(\sum_{i=1}^nx_i^2)(\sum_{i=1}^ny_i^2) - (\sum_{i=1}^nx_i^2)\widehat{\beta}(2\sum_{i=1}^nx_iy_i - \widehat{\beta}\sum_{i=1}^nx_i^2)}}$$
#
# Substituting $\widehat{\beta}$ into the above equation we get
#
# $$= \frac{\sqrt{n-1}\sum_{i=1}^nx_iy_i}{\sqrt{(\sum_{i=1}^nx_i^2)(\sum_{i=1}^ny_i^2) - (\sum_{i=1}^nx_i^2)\bigl(\frac{\sum_{i=1}^nx_iy_i}{\sum_{i=1}^nx_i^2}\bigr)(2\sum_{i=1}^nx_iy_i - \bigl(\frac{\sum_{i=1}^nx_iy_i}{\sum_{i=1}^nx_i^2}\bigr)\sum_{i=1}^nx_i^2)}}$$
#
# Cancelling and combining the denominator we are left with
#
# $$= \frac{\sqrt{n-1}\sum_{i=1}^nx_iy_i}{\sqrt{(\sum_{i=1}^nx_i^2)(\sum_{i=1}^ny_i^2) - (\sum_{i=1}^nx_iy_i)^2}}$$

# %%
(np.sqrt(len(x) - 1) * (x * y).sum()) / np.sqrt((x**2).sum() * (y**2).sum() - (x * y).sum()**2)
# Out:
# 20.649898514706781

# %% [markdown]
# Which is exactly the same as the t-statistic in the summary of the model above.
#
# **11 (e)**:
# There is no place in the formula from (d) where swapping $x$ and $y$ would change the formula or the value of the t-statistic. Mathematically: $t(x, y) = t(y, x)$
#
# **11 (f)**:

# %%
y_ols = smf.ols('y ~ x', pd.DataFrame({'x': x, 'y': y})).fit()
x_ols = smf.ols('x ~ y', pd.DataFrame({'x': x, 'y': y})).fit()
print(y_ols.summary().tables[1])
print(x_ols.summary().tables[1])
# Out:
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0752      0.104      0.722      0.472      -0.131       0.282
# x              2.1147      0.103     20.521      0.000       1.910       2.319
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0175      0.044     -0.395      0.694      -0.106       0.071
# y              0.3836      0.019     20.521      0.000       0.347       0.421
# ...

# %% [markdown]
# **12 (a)**:
# Assuming that $\bar{x} = \bar{y} = 0$, the coefficient estimate for the linear regression of $Y$ onto $X$ is
#
# $$\widehat{\beta} = \frac{\sum_{i=1}^nx_iy_i}{\sum_{i=1}^nx_i^2}$$
#
# while for the regression of $X$ onto $Y$ is
#
# $$\widehat{\beta}^\prime = \frac{\sum_{i\prime=1}^nx_iy_i}{\sum_{i=1}^ny_i^2}$$
#
# So the coefficients will be the same (i.e. $\widehat{\beta} = \widehat{\beta}^\prime$) *iff* $\sum_{i=1}^nx_i^2 = \sum_{i=1}^ny_i^2$
#
# **12 (b)**:

# %%
x = np.random.normal(size=100)
y = -3 * x + np.random.normal(size=100)

print((x**2).sum(), (y**2).sum())

y_ols = smf.ols('y ~ x + 0', {'x': x, 'y': y}).fit()
x_ols = smf.ols('x ~ y + 0', {'x': x, 'y': y}).fit()

print(y_ols.summary().tables[1])
print(x_ols.summary().tables[1])
# Out:
# 90.9817447265 834.884786406
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x             -2.8641      0.099    -28.884      0.000      -3.061      -2.667
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# y             -0.3121      0.011    -28.884      0.000      -0.334      -0.291
# ...

# %% [markdown]
# **12 (c)**:

# %%
x = np.linspace(1, 100, 100)
y = np.linspace(100, 1, 100) + np.random.normal(size=100)

print((x**2).sum(), (y**2).sum())

y_ols = smf.ols('y ~ x + 0', {'x': x, 'y': y}).fit()
x_ols = smf.ols('x ~ y + 0', {'x': x, 'y': y}).fit()

print(y_ols.summary().tables[1])
print(x_ols.summary().tables[1])
# Out:
# 338350.0 338149.029362
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x              0.5075      0.087      5.863      0.000       0.336       0.679
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# y              0.5078      0.087      5.863      0.000       0.336       0.680
# ...

# %% [markdown]
# **13 (a, b, c)**:

# %%
np.random.seed(1)
x = np.random.normal(size=100)
eps = np.random.normal(scale=np.sqrt(0.25), size=100)
y = -1 + 0.5*x + eps

print('Length of y: {}'.format(len(y)))
print('Beta_0: -1\nBeta_1: 0.5')
# Out:
# Length of y: 100
# Beta_0: -1
# Beta_1: 0.5

# %% [markdown]
# **13 (d)**:

# %%
plt.scatter(x, y)

# %% [markdown]
# **13 (e)**:

# %%
y_ols = smf.ols('y ~ x', {'x': x, 'y': y}).fit()
y_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.517
# Method:                 Least Squares   F-statistic:                     107.0
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           2.20e-17
# Time:                        08:59:59   Log-Likelihood:                -65.124
# No. Observations:                 100   AIC:                             134.2
# Df Residuals:                      98   BIC:                             139.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9265      0.047    -19.717      0.000      -1.020      -0.833
# ...

# %%
y_pred = y_ols.predict()
n = len(x)
RSS = ((y - y_pred)**2).sum()
RSE = np.sqrt(1/(n-2))*RSS
print('RSE: {:.4f}\n'.format(RSE))
coef_conf_int_1 = y_ols.conf_int(alpha=0.05)
coef_conf_int_1.columns=['5%', '95%']
print(coef_conf_int_1)
# Out:
# RSE: 2.1756
#
#                  5%       95%
# Intercept -1.019741 -0.833246
# x          0.442613  0.652814

# %% [markdown]
# $\widehat{\beta}_0$ and $\widehat{\beta}_1$ are pretty close to $\beta_0$ and $\beta_1$. The F-statistic for the model is large and has a very small associated p-value, so the null hypothesis ($H_0: \widehat{\beta}_i = 0$) can be rejected.

# %% [markdown]
# **13 (f)**:

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
sns.regplot(x, y, ci=False, line_kws={'color': 'green'})
X = np.linspace(-3, 3, 100)
Y = -1 + 0.5 * X
ax.plot(X, Y, c='r', lw=2)
ax.legend(['Least Squares Regression', 'Population Regression'])

# %% [markdown]
# **13 (g)**:

# %%
y_ols = smf.ols('y ~ x + I(X**2)', {'x': x, 'y': y}).fit()
y_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.524
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     53.35
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           2.36e-16
# Time:                        09:00:00   Log-Likelihood:                -64.919
# No. Observations:                 100   AIC:                             135.8
# Df Residuals:                      97   BIC:                             143.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9599      0.071    -13.544      0.000      -1.101      -0.819
# ...

# %% [markdown]
# The coefficient for $x_i^2$ is not statistically significant based on the high p-value associated with the coefficient. There is no evidence that the quadratic term improves the model even though the $R^2$ was slightly higher with the quadratic term.

# %% [markdown]
# **13 (h)**:

# %%
np.random.seed(1)
x = np.random.normal(size=100)
eps = np.random.normal(scale=np.sqrt(0.1), size=100)
y = -1 + 0.5*x + eps

print('Length of y: {}'.format(len(y)))
print('Beta_0: -1\nBeta_1: 0.5')

y_ols = smf.ols('y ~ x', {'x': x, 'y': y}).fit()
print(y_ols.summary())

fig, ax = plt.subplots(1, 1, figsize=(8, 4))
sns.regplot(x, y, ci=False, line_kws={'color': 'green'})
X = np.linspace(-3, 3, 100)
Y = -1 + 0.5 * X
ax.plot(X, Y, c='r', lw=2)
ax.legend(['Least Squares Regression', 'Population Regression'])

y_pred = y_ols.predict()
n = len(x)
RSS = ((y - y_pred)**2).sum()
RSE = np.sqrt(1/(n-2))*RSS
print('RSE: {:.4f}'.format(RSE))

coef_conf_int_2 = y_ols.conf_int(alpha=0.05)
coef_conf_int_2.columns=['5%', '95%']
print(coef_conf_int_2)
# Out:
# Length of y: 100
# Beta_0: -1
# Beta_1: 0.5
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.719
# Model:                            OLS   Adj. R-squared:                  0.716
# Method:                 Least Squares   F-statistic:                     250.5
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           9.45e-29
# Time:                        09:00:00   Log-Likelihood:                -19.309
# No. Observations:                 100   AIC:                             42.62
# Df Residuals:                      98   BIC:                             47.83
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9535      0.030    -32.085      0.000      -1.012      -0.895
# ...

# %% [markdown]
# Because the original fit for $y$ was already very good, the coefficients are about the same. However, since there is less variance along the regression line, $R^2$ increased from 0.522 to 0.719 and the RSE decreased from 2.176 to 0.870, which indicates a much improved model.
#
# **13 (i)**:

# %%
np.random.seed(1)
x = np.random.normal(size=100)
eps = np.random.normal(scale=1, size=100)
y = -1 + 0.5*x + eps

print('Length of y: {}'.format(len(y)))
print('Beta_0: -1\nBeta_1: 0.5')

y_ols = smf.ols('y ~ x', {'x': x, 'y': y}).fit()
print(y_ols.summary())

fig, ax = plt.subplots(1, 1, figsize=(8, 4))
sns.regplot(x, y, ci=False, line_kws={'color': 'green'})
X = np.linspace(-3, 3, 100)
Y = -1 + 0.5 * X
ax.plot(X, Y, c='r', lw=2)
ax.legend(['Least Squares Regression', 'Population Regression'])

y_pred = y_ols.predict()
n = len(x)
RSS = ((y - y_pred)**2).sum()
RSE = np.sqrt(1/(n-2))*RSS
print('RSE: {:.4f}'.format(RSE))

coef_conf_int_3 = y_ols.conf_int(alpha=0.05)
coef_conf_int_3.columns=['5%', '95%']
print(coef_conf_int_3)
# Out:
# Length of y: 100
# Beta_0: -1
# Beta_1: 0.5
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.236
# Method:                 Least Squares   F-statistic:                     31.60
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           1.79e-07
# Time:                        09:00:00   Log-Likelihood:                -134.44
# No. Observations:                 100   AIC:                             272.9
# Df Residuals:                      98   BIC:                             278.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.8530      0.094     -9.076      0.000      -1.039      -0.666
# ...

# %% [markdown]
# The coefficents are again very similar to the population regression coefficients. However, with increased variance along the regression line, $R^2$ decreased from 0.522 to 0.244 and the RSE increased from 2.176 to 8.702, which indicates a worse model.
#
# **13 (j)**:

# %%
print('Original Data: \n{}\n'.format(coef_conf_int_1))
print('Less Noisy Data: \n{}\n'.format(coef_conf_int_2))
print('More Noisy Data: \n{}\n'.format(coef_conf_int_3))
# Out:
# Original Data:
#                  5%       95%
# Intercept -1.019741 -0.833246
# x          0.442613  0.652814
#
# Less Noisy Data:
#                  5%       95%
# Intercept -1.012485 -0.894535
# x          0.463706  0.596648
#
# More Noisy Data:
#                  5%       95%
# Intercept -1.039482 -0.666491
# x          0.385227  0.805628

# %% [markdown]
# The confidence interval is tighter for the original data and the less noisy dataset and more spread out for the more noisy data.
#
# **14 (a)**:

# %%
np.random.seed(123)
x1 = np.random.uniform(size=100)
x2 = 0.5 * x1 + np.random.normal(size=100) / 10
y = 2 + 2 * x1 + 0.3 * x2 + np.random.normal(size=100)

# %% [markdown]
# The population regression is $y = \beta_0 + \beta_1x_1 + \beta_2x_2 + \epsilon$ where $\beta_0 = 2$, $\beta_1 = 2$, and $\beta_2 = 0.3$.
#
# **14 (b)**:

# %%
plt.scatter(x1, x2)
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
print('Correlation Coefficient between x_1 and x_2: {:.4f}'.format(np.corrcoef(x1, x2)[0,1]))
# Out:
# Correlation Coefficient between x_1 and x_2: 0.7647

# %% [markdown]
# **14 (c)**:

# %%
y_ols = smf.ols('y ~ x1 + x2', {'x1': x1, 'x2': x2, 'y': y}).fit()
y_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.259
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     16.99
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           4.72e-07
# Time:                        09:00:00   Log-Likelihood:                -136.72
# No. Observations:                 100   AIC:                             279.4
# Df Residuals:                      97   BIC:                             287.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.7875      0.220      8.125      0.000       1.351       2.224
# ...

# %% [markdown]
# $\widehat{\beta}_0 = 1.788$, $\widehat{\beta}_1 = 2.023$, $\widehat{\beta}_2 = 0.544$
#
# The estimated coefficients are very close to the population coefficients. However, based on the p-values we can reject the null hypothesis for $\beta_1$ but we cannot reject the null hypothesis for $\beta_2$.
#
# **14 (d)**:

# %%
y_ols = smf.ols('y ~ x1', {'x1': x1, 'y': y}).fit()
y_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.257
# Model:                            OLS   Adj. R-squared:                  0.250
# Method:                 Least Squares   F-statistic:                     33.92
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           7.30e-08
# Time:                        09:00:00   Log-Likelihood:                -136.88
# No. Observations:                 100   AIC:                             277.8
# Df Residuals:                      98   BIC:                             283.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.7968      0.219      8.220      0.000       1.363       2.231
# ...

# %% [markdown]
# Based on the low p-values we can reject the null hypothesis for $\beta_1$.
#
# **14 (e)**:

# %%
y_ols = smf.ols('y ~ x2', {'x2': x2, 'y': y}).fit()
y_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.175
# Model:                            OLS   Adj. R-squared:                  0.167
# Method:                 Least Squares   F-statistic:                     20.85
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           1.45e-05
# Time:                        09:00:00   Log-Likelihood:                -142.10
# No. Observations:                 100   AIC:                             288.2
# Df Residuals:                      98   BIC:                             293.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.1663      0.197     10.973      0.000       1.775       2.558
# ...

# %% [markdown]
# Based on the low p-values we can reject the null hypothesis for $\beta_1$.
#
# **14 (f)**:
# Based on the collinearity between $x1$ and $x2$ as shown in (b), these results are not surprising. It is hard to distinguish their individual effects when regressed upon together. When they are regressed upon separately, their linear relationships with $y$ are indicated more clearly.
#
# **14 (g)**:

# %%
x1 = np.append(x1, 0.1)
x2 = np.append(x2, 0.8)
y = np.append(y, 6)

y_ols_both = smf.ols('y ~ x1 + x2', {'x1': x1, 'x2': x2, 'y': y}).fit()
y_ols_x1 = smf.ols('y ~ x1', {'x1': x1, 'x2': x2, 'y': y}).fit()
y_ols_x2 = smf.ols('y ~ x2', {'x1': x1, 'x2': x2, 'y': y}).fit()

print(y_ols_both.summary())
print(y_ols_x1.summary())
print(y_ols_x2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.236
# Method:                 Least Squares   F-statistic:                     16.42
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           7.09e-07
# Time:                        09:00:00   Log-Likelihood:                -141.87
# No. Observations:                 101   AIC:                             289.7
# Df Residuals:                      98   BIC:                             297.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.8553      0.227      8.170      0.000       1.405       2.306
# ...

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(12, 8))

ip_both = sm.graphics.influence_plot(y_ols_both, ax=ax1)
ip_x1 = sm.graphics.influence_plot(y_ols_x1, ax=ax2)
ip_x2 = sm.graphics.influence_plot(y_ols_x2, ax=ax3)

ax1.set(xlim=[0,0.1], ylim=[-4, 4])
ax2.set(xlim=[0,0.07], ylim=[-4, 6])
ax3.set(xlim=[0,0.15], ylim=[-5, 5])

sns.residplot(y_ols_both.predict(), y_ols_both.resid, lowess=True, 
              line_kws={'color': 'red'}, ax=ax4)
sns.residplot(y_ols_x1.predict(), y_ols_x1.resid, lowess=True, 
              line_kws={'color': 'red'}, ax=ax5)
sns.residplot(y_ols_x2.predict(), y_ols_x2.resid, lowess=True, 
              line_kws={'color': 'red'}, ax=ax6)

ax4.set(xlabel='Fitted Values', ylabel='Residuals')
ax5.set(xlabel='Fitted Values', ylabel='Residuals')
ax6.set(xlabel='Fitted Values', ylabel='Residuals');

# %% [markdown]
# For the model that includes $x_1$ and $x_2$, the newly added observation causes problems in the fitted values vs residuals plot. This point does causes the model which only includes $x_1$ to have a lower $R^2$ because it is an extreme outlier to $x1$ (although not necessarily for $y$). In the model which only includes $x_2$ this new point is a very high leverage point.
#
# **15 (a)**:

# %%
from sklearn.datasets import load_boston
boston_raw = load_boston()
boston = pd.DataFrame(boston_raw['data'], columns=boston_raw['feature_names'])
boston['MEDV'] = boston_raw['target']
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
coefs = {}
for c in boston.columns.drop('CRIM'):
    crim_ols = smf.ols('CRIM ~ {}'.format(c), boston).fit()
    print(crim_ols.summary().tables[1])
    coefs[c] = crim_ols.params[c]
# Out:
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.4292      0.417     10.620      0.000       3.610       5.249
# ZN            -0.0735      0.016     -4.570      0.000      -0.105      -0.042
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.0509      0.668     -3.072      0.002      -3.362      -0.739
# INDUS          0.5068      0.051      9.929      0.000       0.407       0.607
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.7232      0.396      9.404      0.000       2.945       4.501
# CHAS          -1.8715      1.505     -1.243      0.214      -4.829       1.086
# ...

# %% [markdown]
# Based on the results above, the only variable in which we cannot reject the null hypothesis is $CHAS$. All other variables show statistical significance in predicting $CRIM$.
#
# **15 (b)**:

# %%
crim_ols = smf.ols('CRIM ~ {}'.format(' + '.join(boston.columns.drop('CRIM'))), boston).fit()
crim_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   CRIM   R-squared:                       0.448
# Model:                            OLS   Adj. R-squared:                  0.434
# Method:                 Least Squares   F-statistic:                     30.73
# Date:                Mon, 23 Oct 2017   Prob (F-statistic):           2.04e-55
# Time:                        09:00:02   Log-Likelihood:                -1655.7
# No. Observations:                 506   AIC:                             3339.
# Df Residuals:                     492   BIC:                             3399.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     17.4184      7.270      2.396      0.017       3.135      31.702
# ...

# %% [markdown]
# For this model, we can reject the null hypotheses for the variables $ZN, NOX, DIS, RAD, TAX, \text{ and } MEDV$.

# %%
x = []
y = []

fig, ax = plt.subplots(1, 1, figsize=(8, 6))

for c in coefs.keys():
    ax.scatter(coefs[c], crim_ols.params[c])
    ax.annotate(c, xy=(coefs[c], crim_ols.params[c]))

# %% [markdown]
# **15 (d)**:

# %%
def poly(x, p):
    x = np.array(x)
    X = np.transpose(np.vstack((x**k for k in range(p+1))))
    return np.linalg.qr(X)[0][:,1:]

for c in boston.columns.drop('CRIM'):
    crim_ols = smf.ols('CRIM ~ poly({}, 3)'.format(c), boston).fit()
    print(crim_ols.summary().tables[1])
    for i in [1, 2, 3]:
        if crim_ols.pvalues.iloc[i] < 0.05:
            print('{} is significant'.format(crim_ols.pvalues.index[i]))
    print('\n\n')
# Out:
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.5938      0.372      9.658      0.000       2.863       4.325
# poly(ZN, 3)[0]   -38.5330      8.370     -4.604      0.000     -54.978     -22.088
# poly(ZN, 3)[1]   -23.8013      8.370     -2.844      0.005     -40.246      -7.356
# poly(ZN, 3)[2]   -10.0116      8.370     -1.196      0.232     -26.457       6.433
# ...
# poly(ZN, 3)[0] is significant
# poly(ZN, 3)[1] is significant
#
#
#
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             3.5938      0.330     10.876      0.000       2.945       4.243
# poly(INDUS, 3)[0]    78.1392      7.433     10.513      0.000      63.536      92.742
# ...

# %% [markdown]
# So there is evidence of a non-linear relationship between $CRIM$ and $\textbf{X}_j$ where the p-value associated with each polynomial order (1, 2, 3 although in python they are ordered as [0], [1], [2]) is less than 0.05.
